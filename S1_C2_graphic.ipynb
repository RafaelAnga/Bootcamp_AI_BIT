# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelAnga/Bootcamp_AI_BIT/blob/main/S1_C2_graphic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# generate a vector of years (20 years)
import numpy as np
import matplotlib.pyplot as plt
#plot X,Y
plt.figure(figsize=(5,3))
plt.plot(x,A)

x = np.linspace(0,20,21)
# linspace (start point, end point, number of elements)
P = 5000000
i = 0.085
A = P*(1+i)**x
print(A)
# Out:
# [ 5000000.          5425000.          5886125.          6386445.625
#   6929293.503125    7518283.45089062  8157337.54421633  8850711.23547472
#   9603021.69049007 10419278.53418172 11304917.20958716 12265835.17240207
#  13308431.16205625 14439647.81083103 15667017.87475167 16998714.39410556
#  18443605.11760453 20011311.55260091 21712273.03457199 23557816.24251061
#  25560230.62312401]
