# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelAnga/Bootcamp_AI_BIT/blob/main/S3_C3%264_EDA_MPG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad 1.

# %%
import pandas as pd  # Para el manejo de los datos
import numpy as np # Para el manejo de operaciones entre datos, y las columnas
import matplotlib.pyplot as plt # Para el manejo de las graficas
import seaborn as sns # Para el manejo de graficas

# %%
from google.colab import drive # Conectanonos con google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os    # la librería necesaria para la ruta de la carpeta
os.chdir('/content/drive/MyDrive/Bootcamp AI/DataSet')

#mostar lista de archivos
os.listdir()
# Out:
# ['auto-mpg.data-original',
#  'marketing_campaign.xlsx',
#  'marketing_campaign.csv',
#  '.ipynb_checkpoints',
#  'mpg.xlsx']

# %%
#column_names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin", "car name"]
# Leer el archivo usando delimitador de espacios en blanco
file_path = '/content/drive/MyDrive/Bootcamp AI/DataSet/auto-mpg.data-original'
df = pd.read_csv(file_path, delim_whitespace=True, header=None)
# Out:
# <ipython-input-400-ee1000fce648>:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True, header=None)

# %%
df = pd.read_excel('mpg.xlsx')

# %%
df.head()
# Out:
#    mpg:  cylinders:  displacement:  horsepower:  weight:   acceleration:  \
# 0  18.0           8            307        130.0      3504           12.0
# 1  15.0           8            350        165.0      3693           11.5
# 2  18.0           8            318        150.0      3436           11.0
# 3  16.0           8            304        150.0      3433           12.0
# 4  17.0           8            302        140.0      3449           10.5
#
#    model year:   origin:                 car name:
# 0            70        1  chevrolet chevelle malibu
# 1            70        1          buick skylark 320
# 2            70        1         plymouth satellite
# 3            70        1              amc rebel sst
# 4            70        1                ford torino

# %%
df.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mpg:           398 non-null    float64
#  1   cylinders:     406 non-null    int64
#  2   displacement:  406 non-null    int64
#  3   horsepower:    400 non-null    float64
#  4   weight:        406 non-null    int64
#  5   acceleration:  406 non-null    float64
#  6   model year:    406 non-null    int64
#  7   origin:        406 non-null    int64
#  8   car name:      406 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 28.7+ KB

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.scatter(df['mpg:'],df['horsepower:'])
plt.title('Model 1:  horsepower: Vs mpg')
plt.xlabel('mpg')
plt.ylabel('horsepower:')
# Out:
# Text(0, 0.5, 'horsepower:')

# %%
#Drops nan(nulls)
df = df.dropna()

# %%
df.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mpg:           392 non-null    float64
#  1   cylinders:     392 non-null    int64
#  2   displacement:  392 non-null    int64
#  3   horsepower:    392 non-null    float64
#  4   weight:        392 non-null    int64
#  5   acceleration:  392 non-null    float64
#  6   model year:    392 non-null    int64
#  7   origin:        392 non-null    int64
#  8   car name:      392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 30.6+ KB

# %%
#To verify each unique value of the object type
df['car name: '].unique()
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'chevrolet vega 2300', 'toyota corona',
#        'plymouth satellite custom', 'ford torino 500', 'amc matador',
#        'pontiac catalina brougham', 'dodge monaco (sw)',
#        'ford country squire (sw)', 'pontiac safari (sw)',
#        'amc hornet sportabout (sw)', 'chevrolet vega (sw)',
#        'pontiac firebird', 'ford mustang', 'mercury capri 2000',
# ...

# %%
# Update the df so that all the datatypes will be wither float or int
df = df.drop(columns=['car name: '])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 405
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mpg:           392 non-null    float64
#  1   cylinders:     392 non-null    int64
#  2   displacement:  392 non-null    int64
#  3   horsepower:    392 non-null    float64
#  4   weight:        392 non-null    int64
#  5   acceleration:  392 non-null    float64
#  6   model year:    392 non-null    int64
#  7   origin:        392 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 27.6 KB

# %% [markdown]
# First we verified the values of the dataframe using the df.info(). Since we see that the values contain both 400 and 406 non- null values we had to purge the null values. This was done using the .dropna() function. After the values were verified again, we checked the dtatatypes and noticed that there was an object datatype, which we proceeded to drop using the .drop(cloumns) function. Lastly we verified the dataframe again using the df.info to check all of our work.

# %% [markdown]
# ## Actividad 2. Dibujar un histograma y un boxplot de MPG

# %%
#df['cylinders:'] = pd.to_numeric(df['cylinders:'], errors='coerce')

# Plot the boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='cylinders:', y='mpg:')


# Title
plt.title('Boxplot of MPG by Cilinders')

# Show the plot
plt.show()

# %%
# Plotting the histogram
df['mpg:'].hist(bins=20, figsize=(10, 6))

# Adding labels and title
plt.xlabel('MPG (Miles Per Gallon)')  # X-axis label
plt.ylabel('Frequency')  # Y-axis label
plt.title('Distribution of MPG')  # Title

# Display the plot
plt.show()

# %% [markdown]
# # Actividad 2: Draw a historgram and boxplot MPG

# %% [markdown]
# # Part 1: Load and transform

# %% [markdown]
# # Part 2: Selection

# %%
#Used to correlate the data between two variables
corr = df.corr()
corr
# Out:
#                    mpg:  cylinders:  displacement:  horsepower:  weight:   \
# mpg:           1.000000   -0.777618       0.403603    -0.778427 -0.832244
# cylinders:    -0.777618    1.000000      -0.244234     0.842983  0.897527
# displacement:  0.403603   -0.244234       1.000000    -0.287269 -0.387780
# horsepower:   -0.778427    0.842983      -0.287269     1.000000  0.864538
# weight:       -0.832244    0.897527      -0.387780     0.864538  1.000000
# acceleration:  0.197394   -0.219817       0.102016    -0.244505 -0.167748
# model year:    0.580541   -0.345647       0.004126    -0.416361 -0.309120
# origin:        0.565209   -0.568932       0.361652    -0.455171 -0.585005
#
#                acceleration:  model year:    origin:
# mpg:                0.197394      0.580541  0.565209
# cylinders:         -0.219817     -0.345647 -0.568932
# displacement:       0.102016      0.004126  0.361652
# horsepower:        -0.244505     -0.416361 -0.455171
# ...

# %%
#Heat map for correlation
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df.head(5)
# Out:
#    mpg:  cylinders:  displacement:  horsepower:  weight:   acceleration:  \
# 0  18.0           8            307        130.0      3504           12.0
# 1  15.0           8            350        165.0      3693           11.5
# 2  18.0           8            318        150.0      3436           11.0
# 3  16.0           8            304        150.0      3433           12.0
# 4  17.0           8            302        140.0      3449           10.5
#
#    model year:   origin:
# 0            70        1
# 1            70        1
# 2            70        1
# 3            70        1
# 4            70        1

# %%
correlation = df.corr()['mpg:'].sort_values(ascending=False)
correlation
# Out:
# mpg:             1.000000
# model year:      0.580541
# origin:          0.565209
# displacement:    0.403603
# acceleration:    0.197394
# cylinders:      -0.777618
# horsepower:     -0.778427
# weight:         -0.832244
# Name: mpg:, dtype: float64

# %%
#Creates a barplot which shows the correlation index vs the values
sns.barplot(x=correlation.values, y=correlation.index, palette='rocket')
# Out:
# <ipython-input-415-63fc087278c2>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation.values, y=correlation.index, palette='rocket')
# <Axes: ylabel='None'>

# %% [markdown]
# # Describe the process
#
# Conclusion:
#
# *   Model 1: Mpg + tetha_0 + tetha_1 ( X1: weight)
# *   Model 2: Mpg + tetha_0 + tetha_1 ( X1: horsepower)
# *   Model 3: Mpg + tetha_0 + tetha_1 + tetha_2 (X1: weight) (X2:model year)
# *   Model 4: Mpg + tetha_0 + tetha_1 + tetha_2 (X1: weight) (X2:horsepower)
#
#
#
# Weight since it has the highest negative correlation to mpg
# horsepower has the next highest negative correlation to mpg
# Cilinders has the next highest negative correlation to mpg

# %% [markdown]
# # Part 3: Export clear data

# %%
from google.colab import drive # Conectanonos con google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os    # la librería necesaria para la ruta de la carpeta
os.chdir('/content/drive/MyDrive/Bootcamp AI/DataSetClean')
df.to_excel('mpg_clean.xlsx', index=False)
